# %% [markdown]
# # 01 - Data Collection
#
# This notebook is part of the BIST Banking Analytics project.

# %%
from src.data_loader import save_raw_market_data
saved_path = save_raw_market_data()
saved_path
