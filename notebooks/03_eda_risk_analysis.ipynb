# %% [markdown]
# # 03 - EDA and Risk Analysis
#
# This notebook is part of the BIST Banking Analytics project.

# %%
import pandas as pd
from src.risk_metrics import summarize_risk_metrics

data = pd.read_csv('data/processed/stock_prices_weekly.csv')
metrics = summarize_risk_metrics(data)
metrics
